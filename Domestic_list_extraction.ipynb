# %%
import FinanceDataReader as fdr

# %%
import pandas as pd

# %%
df_krx = fdr.StockListing('KRX')

df_krx.head(10)
# Out:
#      Code        ISU_CD       Name Market Dept    Close ChangeCode  Changes  \
# 0  005930  KR7005930003       삼성전자  KOSPI        138800          2     -200
# 1  000660  KR7000660001     SK하이닉스  KOSPI        749000          1     5000
# 2  373220  KR7373220003   LG에너지솔루션  KOSPI        379000          1    16000
# 3  207940  KR7207940008   삼성바이오로직스  KOSPI       1859000          2   -19000
# 4  005935  KR7005931001      삼성전자우  KOSPI        103600          1      600
# 5  005380  KR7005380001        현대차  KOSPI        367000          1     1000
# 6  329180  KR7329180004    HD현대중공업  KOSPI        604000          2    -5000
# 7  012450  KR7012450003  한화에어로스페이스  KOSPI       1212000          2    -2000
# 8  402340  KR7402340004      SK스퀘어  KOSPI        427500          2    -3000
# 9  034020  KR7034020008    두산에너빌리티  KOSPI         88100          1     3900
#
#    ChagesRatio     Open     High      Low    Volume         Amount  \
# ...

# %%
df_krx.shape
# Out:
# (2901, 17)

# %%
df_krx[['Code', 'Name']].to_json('DomesticStocks.json', orient='records', force_ascii=False)
